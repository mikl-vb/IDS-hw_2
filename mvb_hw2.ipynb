# %% [markdown]
# Author: Michael Van Buren
# <br>
# Date: 27 September, 2022

# %% [markdown]
# ### Importing the Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json, ast

sns.set()
# %matplotlib inline

# %%
df_toyotas = pd.read_csv("hw2_cars.csv", encoding = "unicode-escape")

len(df_toyotas)
# Out:
# 859

# %%
df_toyotas.dtypes.to_dict()
# Out:
# {'Car Make': dtype('O'),
#  'Car Model': dtype('O'),
#  'Dealer or Individual': dtype('O'),
#  'Price': dtype('float64'),
#  'Year': dtype('float64'),
#  'Location': dtype('O'),
#  'Mileage': dtype('float64'),
#  'Doors': dtype('O'),
#  'Color': dtype('O'),
#  'Transmission': dtype('O'),
#  'VIN#': dtype('O'),
#  'Engine': dtype('O'),
#  'Description': dtype('O'),
#  'Web link': dtype('O')}

# %%
## make eligible year list - 2008 - 2020
year_list = [2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]

##remove records that do not exist within the eligibility for years to be loaded
df_toyotas_subset = df_toyotas.loc[df_toyotas['Year'].isin(year_list)]

df_toyotas_subset['Year'].value_counts()
# Out:
# 2019.0    150
# 2020.0    105
# 2018.0     88
# 2016.0     76
# 2013.0     65
# 2017.0     63
# 2015.0     60
# 2014.0     57
# 2012.0     51
# 2011.0     41
# 2010.0     31
# 2009.0     16
# 2008.0      9
# Name: Year, dtype: int64

# %%
## create a subset dataframe with fields we are interested in 
df_toyotas_subset = df_toyotas[['Car Model', 'Dealer or Individual', 'Price', 
                                'Year', 'Location', 'Mileage', 'Color', 'Transmission', 'VIN#',
                                'Engine', 'Web link']]

df_toyotas_subset
# Out:
#       Car Model Dealer or Individual    Price    Year  \
# 0          Rav4               Dealer  21300.0  2016.0
# 1          Rav4               Dealer  10995.0  2009.0
# 2    Highlander               Dealer  21990.0  2012.0
# 3       Corolla           Individual  15590.0  2013.0
# 4         Camry               Dealer  19990.0  2012.0
# ..          ...                  ...      ...     ...
# 854        Rav4           Individual  18863.0  2014.0
# 855        Rav4           Individual  27935.0  2019.0
# 856        Rav4           Individual  27488.0  2018.0
# 857        Rav4                  NaN  16993.0  2014.0
# 858        Rav4                  NaN      NaN  2019.0
#
#                        Location   Mileage   Color Transmission  \
# 0              Walnut Creek, CA   90441.0   White    Automatic
# 1          1125 Detroit Ave, CA  172844.0   White    Automatic
# 2    Lower Bottoms, Oakland, CA   75000.0   White    Automatic
# 3                    Pittsburgh   79767.0  Silver    Automatic
# 4             San Francisco, CA   76000.0    Blue    Automatic
# ..                          ...       ...     ...          ...
# 854                         NaN   80930.0   Black    Automatic
# 855                         NaN       NaN     NaN    Automatic
# 856                         NaN       NaN     NaN    Automatic
# 857                         NaN       NaN     NaN          NaN
# 858                         NaN       NaN     NaN          NaN
#
#                   VIN#                     Engine  \
# 0    2T3WFREV0GW274936           2.5 L 4-cylinder
# 1    JTMBK31V095081967              V6, 3.5 Liter
# 2    5TDBK3EH9CS140312              V6, 3.5 Liter
# 3    2T1BU4EE6DC074253  1.8-Liter 4-Cylinder DOHC
# 4    5TDZA3EH0CS021002           4-Cyl, 2.7 Liter
# ..                 ...                        ...
# 854  2T3DFREV9EW220829                        NaN
# 855                NaN                        NaN
# 856                NaN                        NaN
# 857                NaN                        NaN
# 858                NaN                        NaN
#
#                                               Web link
# 0    https://sfbay.craigslist.org/eby/ctd/753307708...
# 1    https://sfbay.craigslist.org/eby/ctd/753307624...
# 2    https://sfbay.craigslist.org/eby/ctd/753332603...
# 3    https://www.carvana.com/vehicle/2417328#inspec...
# 4    https://sfbay.craigslist.org/sfc/ctd/753333249...
# ..                                                 ...
# 854   https://www.carfax.com/vehicle/2T3DFREV9EW220829
# 855   https://www.carfax.com/vehicle/2T3F1RFV0KC034955
# 856   https://www.carfax.com/vehicle/JTMDJREV7JD190557
# 857   https://www.carfax.com/vehicle/2T3DFREV4EW162726
# 858   https://www.carfax.com/vehicle/2T3G1RFV4KW072420
#
# [859 rows x 11 columns]

# %% [markdown]
# ### Cleaning the data

# %%
## find number of NaN rows - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:20/23:40
df_toyotas_subset.isna().sum()
# Out:
# Car Model                1
# Dealer or Individual     5
# Price                    8
# Year                     2
# Location                33
# Mileage                 12
# Color                    7
# Transmission             7
# VIN#                    27
# Engine                  45
# Web link                 4
# dtype: int64

# %%
## expand column width so I can copy the URL and fix data that is missing
## source: https://calmcode.io/til/pandas-max-colwidth.html
pd.set_option('display.max_colwidth', None)

# %%
## Investigate NaN 'Car Model' column  - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['Car Model'].isna()]
# Out:
#     Car Model Dealer or Individual    Price    Year      Location  Mileage  \
# 365       NaN               Dealer  19949.0  2020.0  Waukesha, WI  63573.0
#
#                          Color Transmission               VIN#  \
# 365  Black Sand Pearl Exterior    Automatic  JTDEPRAE4LJ045358
#
#                          Engine  \
# 365  1.8L 4-Cylinder Gas Engine
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Web link
# 365  https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=657096572&allListingType=all-cars&makeCodeList=TOYOTA&city=Pittsburgh&state=PA&zip=15203&location=&searchRadius=0&marketExtension=include&startYear=2008&endYear=2020&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=25&firstRecord=150&dma=&referrer=%2Fcars-for-sale%2Fall-cars%2Ftoyota%2Fpittsburgh-pa-15203%3Fdma%3D%26searchRadius%3D0%26location%3D%26marketExtension%3Dinclude%26startYear%3D2008%26endYear%3D2020%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D25%26firstRecord%3D150&clickType=spotlight

# %%
## rename columnns to add functionality
## source: https://stackoverflow.com/questions/38134643/data-frame-object-has-no-attribute
df_toyotas_subset.rename(columns=
                         {'Car Model' : 'Car_Model'}
                        )
# Out:
#       Car_Model Dealer or Individual    Price    Year  \
# 0          Rav4               Dealer  21300.0  2016.0
# 1          Rav4               Dealer  10995.0  2009.0
# 2    Highlander               Dealer  21990.0  2012.0
# 3       Corolla           Individual  15590.0  2013.0
# 4         Camry               Dealer  19990.0  2012.0
# ..          ...                  ...      ...     ...
# 854        Rav4           Individual  18863.0  2014.0
# 855        Rav4           Individual  27935.0  2019.0
# 856        Rav4           Individual  27488.0  2018.0
# 857        Rav4                  NaN  16993.0  2014.0
# 858        Rav4                  NaN      NaN  2019.0
#
#                        Location   Mileage   Color Transmission  \
# 0              Walnut Creek, CA   90441.0   White    Automatic
# 1          1125 Detroit Ave, CA  172844.0   White    Automatic
# 2    Lower Bottoms, Oakland, CA   75000.0   White    Automatic
# 3                    Pittsburgh   79767.0  Silver    Automatic
# 4             San Francisco, CA   76000.0    Blue    Automatic
# ..                          ...       ...     ...          ...
# 854                         NaN   80930.0   Black    Automatic
# 855                         NaN       NaN     NaN    Automatic
# 856                         NaN       NaN     NaN    Automatic
# 857                         NaN       NaN     NaN          NaN
# 858                         NaN       NaN     NaN          NaN
#
#                   VIN#                     Engine  \
# 0    2T3WFREV0GW274936           2.5 L 4-cylinder
# 1    JTMBK31V095081967              V6, 3.5 Liter
# 2    5TDBK3EH9CS140312              V6, 3.5 Liter
# 3    2T1BU4EE6DC074253  1.8-Liter 4-Cylinder DOHC
# 4    5TDZA3EH0CS021002           4-Cyl, 2.7 Liter
# ..                 ...                        ...
# 854  2T3DFREV9EW220829                        NaN
# 855                NaN                        NaN
# 856                NaN                        NaN
# 857                NaN                        NaN
# 858                NaN                        NaN
#
#                                                          Web link
# 0            https://sfbay.craigslist.org/eby/ctd/7533077081.html
# 1            https://sfbay.craigslist.org/eby/ctd/7533076248.html
# 2            https://sfbay.craigslist.org/eby/ctd/7533326039.html
# 3    https://www.carvana.com/vehicle/2417328#inspection-150-point
# 4            https://sfbay.craigslist.org/sfc/ctd/7533332493.html
# ..                                                            ...
# 854              https://www.carfax.com/vehicle/2T3DFREV9EW220829
# 855              https://www.carfax.com/vehicle/2T3F1RFV0KC034955
# 856              https://www.carfax.com/vehicle/JTMDJREV7JD190557
# 857              https://www.carfax.com/vehicle/2T3DFREV4EW162726
# 858              https://www.carfax.com/vehicle/2T3G1RFV4KW072420
#
# [859 rows x 11 columns]

# %%
## fix the Car Model where was NaN after clicking on the link to view the web link
## source: https://www.geeksforgeeks.org/how-to-replace-values-in-column-based-on-condition-in-pandas/


#df_toyotas_subset.loc[df_toyotas_subset['VIN#'] == 'JTDEPRAE4LJ045358']

#set('Car_Model' == 'Corolla').df_toyotas_subset['VIN#'] == 'JTDEPRAE4LJ045358'

#df_toyotas_subset.loc[df_toyotas_subset['VIN#'] == 'JTDEPRAE4LJ045358'].set(df_toyotas_subset['Car_Model'] == 'Corolla')

##df_toyotas_subset.mask(df_toyotas_subset['Car Model'].isna(), 'Corolla')

##, 'Car Model'] == 'Corolla'

###df_toyotas_subset['Car Model'].replace('NaN', 'Corolla', inplace=True)

# %%
df_toyotas_subset[df_toyotas_subset['Car Model'].isna()]
# Out:
#     Car Model Dealer or Individual    Price    Year      Location  Mileage  \
# 365       NaN               Dealer  19949.0  2020.0  Waukesha, WI  63573.0
#
#                          Color Transmission               VIN#  \
# 365  Black Sand Pearl Exterior    Automatic  JTDEPRAE4LJ045358
#
#                          Engine  \
# 365  1.8L 4-Cylinder Gas Engine
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Web link
# 365  https://www.autotrader.com/cars-for-sale/vehicledetails.xhtml?listingId=657096572&allListingType=all-cars&makeCodeList=TOYOTA&city=Pittsburgh&state=PA&zip=15203&location=&searchRadius=0&marketExtension=include&startYear=2008&endYear=2020&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=25&firstRecord=150&dma=&referrer=%2Fcars-for-sale%2Fall-cars%2Ftoyota%2Fpittsburgh-pa-15203%3Fdma%3D%26searchRadius%3D0%26location%3D%26marketExtension%3Dinclude%26startYear%3D2008%26endYear%3D2020%26isNewSearch%3Dfalse%26showAccelerateBanner%3Dfalse%26sortBy%3Drelevance%26numRecords%3D25%26firstRecord%3D150&clickType=spotlight

# %%
## Investigate NaN 'Dealer or Individiaul' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['Dealer or Individual'].isna()]
# Out:
#       Car Model Dealer or Individual    Price    Year  \
# 209  Highlander                  NaN  22998.0  2013.0
# 624       Camry                  NaN      NaN     NaN
# 719     Corolla                  NaN  21899.0  2022.0
# 857        Rav4                  NaN  16993.0  2014.0
# 858        Rav4                  NaN      NaN  2019.0
#
#                     Location   Mileage                   Color Transmission  \
# 209  CarMax Harrisonburg, VA   95000.0                   Black    Automatic
# 624            Uniontown, PA  222911.0  Barcelona Red Metallic    Automatic
# 719                 San Jose       0.0                  silver    Automatic
# 857                      NaN       NaN                     NaN          NaN
# 858                      NaN       NaN                     NaN          NaN
#
#                   VIN#                          Engine  \
# 209  5TDBK3EH9DS180049                6-cyl, Gas, 3.5L
# 624  4T1BF1FK2CU620590                    2.5L 4cyl 6A
# 719  5YFEPMAEXNP338036  Regular Unleaded I-4 1.8 L/110
# 857                NaN                             NaN
# 858                NaN                             NaN
#
#                                                                        Web link
# 209                                         https://www.carmax.com/car/23234504
# 624  https://www.edmunds.com/toyota/camry/2012/vin/4T1BF1FK2CU620590/?radius=50
# 719                https://www.toyotamilpitas.com/inventory/new-toyota-corolla/
# 857                            https://www.carfax.com/vehicle/2T3DFREV4EW162726
# 858                            https://www.carfax.com/vehicle/2T3G1RFV4KW072420

# %%
## Investigate NaN 'Price' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['Price'].isna()]
# Out:
#       Car Model Dealer or Individual  Price     Year  \
# 322       Camry               Dealer    NaN  28998.0
# 335       Camry               Dealer    NaN  16990.0
# 419  Highlander               Dealer    NaN      NaN
# 508     Corolla               Dealer    NaN   2016.0
# 527  Highlander               Dealer    NaN   2018.0
# 559     Corolla               Dealer    NaN   2009.0
# 624       Camry                  NaN    NaN      NaN
# 858        Rav4                  NaN    NaN   2019.0
#
#                                           Location   Mileage  \
# 322                                 East Haven, CT   71000.0
# 335                                Bridgeville, PA  104473.0
# 419                                          39998   15000.0
# 508                                        Florida   61262.0
# 527                                 Greensburg, PA   48512.0
# 559  1761 West Liberty Avenue Pittsburgh, PA 15226   12000.0
# 624                                  Uniontown, PA  222911.0
# 858                                            NaN       NaN
#
#                       Color Transmission                VIN#  \
# 322                     red    Automatic   4T1B61HK9JU544313
# 335                    Gray    Automatic   4T1BF1FK1FU050005
# 419                   white    Automatic   5TDBZRBH0LS520450
# 508                    gray       Manual   5YFBURHE7GP369374
# 527          Blizzard Pearl    Automatic                 NaN
# 559                    grey       Manual                 NaN
# 624  Barcelona Red Metallic    Automatic   4T1BF1FK2CU620590
# 858                     NaN          NaN                 NaN
#
#                                   Engine  \
# 322                     4-cyl, Gas, 2.5L
# 335                          4-Cyl, 2.5L
# 419                     6-cyl, Gas, 3.5L
# 508  1.8L 4-cyl DOHC 16-Valve Dual VVT-i
# 527                                  Gas
# 559                                 4D S
# 624                         2.5L 4cyl 6A
# 858                                  NaN
#
#                                                                                                                                                                                                                                                                                                                                Web link
# 322                                                                                                                                                                                                                                                                                                 https://www.carmax.com/car/23219999
# 335                                                                                                                                                                                                                                                                                             https://www.carvana.com/vehicle/2470299
# 419                                                                                                                                                                                                                                                                                                 https://www.carmax.com/car/23066409
# 508  https://www.carvana.com/vehicle/lt/2336216&store=Carvpit?utm_source=google&utm_medium=vla&utm_campaign=11030956979&utm_content=111143241747&utm_target=pla-1731472881263&utm_creative=461539942938&utm_device=c&utm_adposition=&gclid=Cj0KCQjw94WZBhDtARIsAKxWG-9iNgMmMfDH_W8ioYjq8UbQNGkCSChN1-acjqPpw7boGsjENotmyDcaAsZ1EALw_wcB
# 527                                                                                                                                                                                                                                                     https://www.edmunds.com/toyota/highlander/2018/vin/5TDJZRFH4JS911457/?radius=50
# 559                                                                                                                                                                                                                                     https://www.webuyanycarusa.com/secure/bookappointment/8993ee21-8ef5-4e3c-ba86-135aeeb91020#view
# 624                                                                                                                                                                                                                                                          https://www.edmunds.com/toyota/camry/2012/vin/4T1BF1FK2CU620590/?radius=50
# 858                                                                                                                                                                                                                                                                                    https://www.carfax.com/vehicle/2T3G1RFV4KW072420

# %%
## drop NaN values
df_toyotas_subset = df_toyotas_subset['Price'].dropna()

# %%
## verify NaN values were dropped
df_toyotas_subset.isna().sum()
# Out:
# 0

# %%
## Investigate NaN 'Year' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['Year'].isna()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 ## Investigate NaN 'Year' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
# ----> 2 df_toyotas_subset[df_toyotas_subset['Year'].isna()]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Year'

# %%
## Investigate NaN 'Location' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['Location'].isna()]

# %%
## Investigate NaN 'Color' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['Color'].isna()]

# %%
## Investigate NaN 'Transmission' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['Transmission'].isna()]

# %%
## Investigate NaN 'Vin#' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['VIN#'].isna()]

# %%
## Investigate NaN 'Engine' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['Engine'].isna()]

# %%
## Investigate NaN 'Year' column - source: https://www.youtube.com/watch?v=qxpKCBV60U4 @ 8:30
df_toyotas_subset[df_toyotas_subset['Year'].isna()]

# %% [markdown]
# 1. Creat a df_subset of data removing fields I do not need...
#     * (Car Make (All are Toyota))
#     * Number of doors (all are 4)
#     * Remove Transmission data - most are Automatic / CVT transmissions. Only ~ 1% of cars sold in US are Manual and there are a number of null fields. I don't plan to extract any data based on this column.
#
# 1. Make sure all Car Model instances are spelled correctly
# 1. Make sure the date range is correct - 2008 - 2020
# 1. Clean duplicate VIN#s - keeping only last instance in my case

# %%
## count how many duplicate Vin#s there are in the dataframe
###df_toyotas_subset[df_toyotas_subset['VIN#'].duplicated(keep=False)]

df_toyotas_subset['VIN#'].duplicated().sum()

# %%
## delete duplicate VIN#s by keeping last
df_toyotas_subset = df_toyotas_subset.drop_duplicates(subset="VIN#", keep="last")

# %%
# verify duplicate Vin# rows were deleted
###df_toyotas_subset[df_toyotas_subset['VIN#'].duplicated(keep=False)]

df_toyotas_subset['VIN#'].duplicated().sum()

# %% [markdown]
# ### Part 2. EDA

# %% [markdown]
# ### Part 3. Pose a question that can you believe that can be answered from the data. This should be in a clearly identified section in the same notebook.
#
# Question: Do cars cost more in certain geographic areas?

# %% [markdown]
# ### Part 4) Suggest some improvements that could be made in order to better collect this data. This should be in a clearly identified section in the same notebook.

# %% [markdown]
# Good
# <br>
# 1. drop down of cars
#
# <br>
# <br>
#
# Bad
#
# 1. format of mileage should be into specific consistent format
# 1. requiring fields
# 1. automatic vs. CVT - transmission should be accurate based on cars that actually exists
# 1. remove questionst that can be easily answered based on the Car Model - e.g. 4 door for all cars, engine cylinder if you insist on having engine being input - have a drop down based on what is offered by Toyota
# 1. naming fields should not have space for df.FIELD functionality
# 1. only allow valid data to be entered - e.g. year of the Toyota looking at, similar to the model
